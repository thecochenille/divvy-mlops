# %% [markdown]
# # download the data

# %%
import requests
import datetime

import pandas as pd
import zipfile
from tqdm import tqdm


import mlflow
import os

# %%
files= [('202304','./data/raw'),('202305','./data/raw')]

for file, path in files:
    url=f'https://divvy-tripdata.s3.amazonaws.com/{file}-divvy-tripdata.zip'
    resp=requests.get(url, stream=True)
    zip_save_path = f'{path}/{file}.zip'

    os.makedirs(path, exist_ok=True)

    with open(zip_save_path,"wb") as handle:
        for data in tqdm(resp.iter_content(chunk_size=1024),
                         desc=f'{file}',
                         postfix=f"save to {zip_save_path}",
                         total=int(resp.headers["Content-Length"])):
            handle.write(data)

    with zipfile.ZipFile(zip_save_path, 'r') as zip_ref:
        zip_ref.extractall(path)
    
    os.remove(zip_save_path)
# Out:
# 202304:   0%|          | 15038/15398190 [00:02<51:00, 5026.24it/s, save to ./data/raw/202304.zip]
# 202305:   0%|          | 22894/23442906 [00:04<1:14:30, 5239.28it/s, save to ./data/raw/202305.zip]

# %%
data = pd.read_csv("data/raw/202304-divvy-tripdata.csv")

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  8FE8F7D9C10E88C7  electric_bike  2023-04-02 08:37:28  2023-04-02 08:41:37
# 1  34E4ED3ADF1D821B  electric_bike  2023-04-19 11:29:02  2023-04-19 11:52:12
# 2  5296BF07A2F77CB5  electric_bike  2023-04-19 08:41:22  2023-04-19 08:43:22
# 3  40759916B76D5D52  electric_bike  2023-04-19 13:31:30  2023-04-19 13:35:09
# 4  77A96F460101AC63  electric_bike  2023-04-19 12:05:36  2023-04-19 12:10:26
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# 0      41.80     -87.60    41.79   -87.60        member
# 1      41.87     -87.65    41.93   -87.68        member
# 2      41.93     -87.66    41.93   -87.66        member
# 3      41.92     -87.65    41.91   -87.65        member
# 4      41.91     -87.65    41.91   -87.63        member

# %%
data.describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  426590.000000  426590.000000  426155.000000  426155.000000
# mean       41.901507     -87.646961      41.902002     -87.647225
# std         0.047098       0.027689       0.047241       0.027808
# min        41.648501     -87.830000      41.648501     -88.110000
# 25%        41.880000     -87.660224      41.880317     -87.660984
# 50%        41.897733     -87.644140      41.898969     -87.644336
# 75%        41.930000     -87.629859      41.930000     -87.629912
# max        42.070000     -87.520000      42.080000     -87.528232

# %%
# missing data for started at or station name
data.isnull().sum()
# Out:
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name    63814
# start_station_id      63814
# end_station_name      68630
# end_station_id        68630
# start_lat                 0
# start_lng                 0
# end_lat                 435
# end_lng                 435
# member_casual             0
# dtype: int64

# %%
#removing rows without station name
data=data.dropna(subset=['start_station_name','end_station_name'])

# %%
data.isnull().sum() #no missing data left
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
data.describe() #enough data to train my model
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  324197.000000  324197.000000  324197.000000  324197.000000
# mean       41.900372     -87.644843      41.900953     -87.645155
# std         0.044510       0.025272       0.044666       0.025395
# min        41.648501     -87.830000      41.648501     -87.830000
# 25%        41.879644     -87.658416      41.880330     -87.658617
# 50%        41.895748     -87.642746      41.896373     -87.642884
# 75%        41.926756     -87.628594      41.928830     -87.629155
# max        42.064854     -87.528232      42.064854     -87.528232

# %% [markdown]
# # Target engineering

# %% [markdown]
# I decided to create a target value that is the net usage of bikes per station per hour of the day.
# This target will be called `net_usage`

# %% [markdown]
# ## Define target variable
# Target will be the number of rental at start station by hour

# %% [markdown]
# ## Features
#
# 1 - Time features extracted from started at and ended at (day, day of the week)
# 2 - Rideable type (optional)
# 3 - Start station name
# 4 - End station name

# %%
data.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
# extract hour and day of the week for started_at and ended_at
data['started_at'] = pd.to_datetime(data['started_at'])
data['ended_at'] = pd.to_datetime(data['ended_at'])

# %%
data['started_hour'] = data['started_at'].dt.hour
data['started_day_of_week'] = data['started_at'].dt.day_name()

data['ended_hour'] = data['ended_at'].dt.hour
data['ended_day_of_week'] = data['ended_at'].dt.day_name()

# %%
# dataset grouping features
rentals = data.groupby(['start_station_name', 'started_hour', 'started_day_of_week']).size().reset_index(name='average_rentals')


returns = data.groupby(['end_station_name', 'ended_hour', 'ended_day_of_week']).size().reset_index(name='average_returns')

# %%
usage_data = pd.merge(rentals, returns, left_on=['start_station_name', 'started_hour', 'started_day_of_week'], right_on=['end_station_name', 'ended_hour', 'ended_day_of_week'], how='outer')

# %%
usage_data['average_rentals'] = usage_data['average_rentals'].fillna(0)
usage_data['average_returns'] = usage_data['average_returns'].fillna(0)

# %%
usage_data['net_usage'] = usage_data['average_rentals'] - usage_data['average_returns']

# %%
usage_data.head()
# Out:
#     start_station_name  started_hour started_day_of_week  average_rentals  \
# 0  2112 W Peterson Ave           0.0              Sunday              1.0
# 1                  NaN           NaN                 NaN              0.0
# 2                  NaN           NaN                 NaN              0.0
# 3                  NaN           NaN                 NaN              0.0
# 4                  NaN           NaN                 NaN              0.0
#
#       end_station_name  ended_hour ended_day_of_week  average_returns  \
# 0                  NaN         NaN               NaN              0.0
# 1  2112 W Peterson Ave         0.0          Thursday              1.0
# 2  2112 W Peterson Ave         0.0           Tuesday              1.0
# 3  2112 W Peterson Ave         0.0         Wednesday              1.0
# 4  2112 W Peterson Ave         1.0            Sunday              1.0
#
#    net_usage
# 0        1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0

# %%
data.head()
# Out:
#               ride_id  rideable_type          started_at            ended_at  \
# 227  5B6500E1E58655C0   classic_bike 2023-04-10 17:34:35 2023-04-10 18:02:36
# 383  AA65D25D69AF771F   classic_bike 2023-04-12 12:29:46 2023-04-12 12:54:00
# 409  079FB2C196414482  electric_bike 2023-04-13 17:39:23 2023-04-13 17:40:57
# 561  599623864C871207   classic_bike 2023-04-29 20:57:10 2023-04-29 20:57:13
# 692  63ECC8A13D11A76A   classic_bike 2023-04-20 17:03:11 2023-04-20 17:24:58
#
#                start_station_name start_station_id  \
# 227           Avenue O & 134th St            20214
# 383   Cottage Grove Ave & 51st St     TA1309000067
# 409          Morgan Ave & 14th Pl     TA1306000002
# 561   Cottage Grove Ave & 51st St     TA1309000067
# 692  California Ave & Division St            13256
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 227             Avenue O & 134th St          20214  41.651868 -87.539671
# 383     Cottage Grove Ave & 51st St   TA1309000067  41.803038 -87.606615
# 409            Morgan Ave & 14th Pl   TA1306000002  41.862430 -87.651152
# 561     Cottage Grove Ave & 51st St   TA1309000067  41.803038 -87.606615
# 692  California Ave & Milwaukee Ave          13084  41.903029 -87.697474
#
#        end_lat    end_lng member_casual  started_hour started_day_of_week  \
# 227  41.651868 -87.539671        member            17              Monday
# 383  41.803038 -87.606615        member            12           Wednesday
# 409  41.862378 -87.651062        member            17            Thursday
# 561  41.803038 -87.606615        member            20            Saturday
# 692  41.922695 -87.697153        casual            17            Thursday
#
#      ended_hour ended_day_of_week
# 227          18            Monday
# 383          12         Wednesday
# 409          17          Thursday
# 561          20          Saturday
# 692          17          Thursday

# %%
#extract station, hour and day of the week of either or start or end

def extract_station_info(df):

  df['station_name'] = df.apply(lambda row: row['end_station_name'] if not pd.isna(row['end_station_name']) else row['start_station_name'], axis=1)
  df['hour'] = df.apply(lambda row: row['ended_hour'] if not pd.isna(row['end_station_name']) else row['started_hour'], axis=1)
  df['day_of_week'] = df.apply(lambda row: row['ended_day_of_week'] if not pd.isna(row['end_station_name']) else row['started_day_of_week'], axis=1)

  return df[['net_usage', 'station_name', 'hour', 'day_of_week']]

# %%
usage_data_2 = extract_station_info(usage_data.copy())

# %%
usage_data_2.shape
# Out:
# (70050, 4)

# %%
usage_data_2.head()
# Out:
#    net_usage         station_name  hour day_of_week
# 0        1.0  2112 W Peterson Ave   0.0      Sunday
# 1       -1.0  2112 W Peterson Ave   0.0    Thursday
# 2       -1.0  2112 W Peterson Ave   0.0     Tuesday
# 3       -1.0  2112 W Peterson Ave   0.0   Wednesday
# 4       -1.0  2112 W Peterson Ave   1.0      Sunday

# %%
usage_data_2.to_parquet('')

# %% [markdown]
# # Model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
features = usage_data_2[['station_name', 'hour', 'day_of_week']]
target = usage_data_2['net_usage']

features = pd.get_dummies(features, columns=['station_name', 'day_of_week']) #encoding categorical
# Out:
#    hour  station_name_2112 W Peterson Ave  station_name_410  \
# 0   0.0                              True             False
# 1   0.0                              True             False
# 2   0.0                              True             False
# 3   0.0                              True             False
# 4   1.0                              True             False
#
#    station_name_63rd St Beach  station_name_900 W Harrison St  \
# 0                       False                           False
# 1                       False                           False
# 2                       False                           False
# 3                       False                           False
# 4                       False                           False
#
#    station_name_Aberdeen St & Jackson Blvd  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    station_name_Aberdeen St & Monroe St  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    station_name_Aberdeen St & Randolph St  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    station_name_Ada St & Washington Blvd  station_name_Adler Planetarium  ...  \
# 0                                  False                           False  ...
# 1                                  False                           False  ...
# 2                                  False                           False  ...
# 3                                  False                           False  ...
# 4                                  False                           False  ...
#
#    station_name_Woodlawn Ave & Lake Park Ave  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    station_name_Yates Blvd & 75th St  station_name_Yates Blvd & 93rd St  \
# 0                              False                              False
# 1                              False                              False
# 2                              False                              False
# 3                              False                              False
# 4                              False                              False
#
#    day_of_week_Friday  day_of_week_Monday  day_of_week_Saturday  \
# 0               False               False                 False
# 1               False               False                 False
# 2               False               False                 False
# 3               False               False                 False
# 4               False               False                 False
#
#    day_of_week_Sunday  day_of_week_Thursday  day_of_week_Tuesday  \
# 0                True                 False                False
# 1               False                  True                False
# 2               False                 False                 True
# 3               False                 False                False
# 4                True                 False                False
#
#    day_of_week_Wednesday
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False
#
# [5 rows x 1063 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
predictions = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 17.831992748037116
